# %% [markdown]
# # Exploratory Data Analysis (EDA) on Retail Sales Data

# %% [markdown]
# ### 1. Data Loading and Cleaning

# %%
import pandas as pd
import numpy as np

# %%
# Load dataset
df = pd.read_csv("menu.csv")

# %%
# Preview
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
# 2                             42        0.0  ...             29
# 3                             52        0.0  ...             30
# 4                             42        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# 2                             10              4
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
#  12  Sodium                         260 non-null    int64
#  13  Sodium (% Daily Value)         260 non-null    int64
#  14  Carbohydrates                  260 non-null    int64
#  15  Carbohydrates (% Daily Value)  260 non-null    int64
#  16  Dietary Fiber                  260 non-null    int64
#  17  Dietary Fiber (% Daily Value)  260 non-null    int64
#  18  Sugars                         260 non-null    int64
#  19  Protein                        260 non-null    int64
#  20  Vitamin A (% Daily Value)      260 non-null    int64
#  21  Vitamin C (% Daily Value)      260 non-null    int64
#  22  Calcium (% Daily Value)        260 non-null    int64
#  23  Iron (% Daily Value)           260 non-null    int64
# dtypes: float64(3), int64(18), object(3)
# memory usage: 48.9+ KB

# %%
# Standardize column names
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
# Check missing values
print(df.isnull().sum())
# Out:
# category                         0
# item                             0
# serving_size                     0
# calories                         0
# calories_from_fat                0
# total_fat                        0
# total_fat_(%_daily_value)        0
# saturated_fat                    0
# saturated_fat_(%_daily_value)    0
# trans_fat                        0
# cholesterol                      0
# cholesterol_(%_daily_value)      0
# sodium                           0
# sodium_(%_daily_value)           0
# carbohydrates                    0
# carbohydrates_(%_daily_value)    0
# dietary_fiber                    0
# dietary_fiber_(%_daily_value)    0
# sugars                           0
# protein                          0
# vitamin_a_(%_daily_value)        0
# vitamin_c_(%_daily_value)        0
# calcium_(%_daily_value)          0
# iron_(%_daily_value)             0
# dtype: int64

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
# Convert numeric columns
numeric_cols = df.columns.drop(["category", "item"])
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors="coerce")

# %%
# Handle missing values (median imputation)
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
print("Cleaned dataset shape:", df.shape)
# Out:
# Cleaned dataset shape: (260, 24)

# %% [markdown]
# # 2. Descriptive Statistics

# %%
from scipy import stats

# %%
# Basic statistics
desc_stats = df.describe()
print(desc_stats)
# Out:
#        serving_size     calories  calories_from_fat   total_fat  \
# count           0.0   260.000000         260.000000  260.000000
# mean            NaN   368.269231         127.096154   14.165385
# std             NaN   240.269886         127.875914   14.205998
# min             NaN     0.000000           0.000000    0.000000
# 25%             NaN   210.000000          20.000000    2.375000
# 50%             NaN   340.000000         100.000000   11.000000
# 75%             NaN   500.000000         200.000000   22.250000
# max             NaN  1880.000000        1060.000000  118.000000
#
#        total_fat_(%_daily_value)  saturated_fat  \
# count                 260.000000     260.000000
# mean                   21.815385       6.007692
# std                    21.885199       5.321873
# min                     0.000000       0.000000
# 25%                     3.750000       1.000000
# 50%                    17.000000       5.000000
# 75%                    35.000000      10.000000
# max                   182.000000      20.000000
#
#        saturated_fat_(%_daily_value)   trans_fat  cholesterol  \
# count                     260.000000  260.000000   260.000000
# mean                       29.965385    0.203846    54.942308
# std                        26.639209    0.429133    87.269257
# min                         0.000000    0.000000     0.000000
# 25%                         4.750000    0.000000     5.000000
# 50%                        24.000000    0.000000    35.000000
# 75%                        48.000000    0.000000    65.000000
# max                       102.000000    2.500000   575.000000
#
#        cholesterol_(%_daily_value)  ...  carbohydrates  \
# count                   260.000000  ...     260.000000
# mean                     18.392308  ...      47.346154
# std                      29.091653  ...      28.252232
# min                       0.000000  ...       0.000000
# 25%                       2.000000  ...      30.000000
# 50%                      11.000000  ...      44.000000
# 75%                      21.250000  ...      60.000000
# max                     192.000000  ...     141.000000
#
#        carbohydrates_(%_daily_value)  dietary_fiber  \
# count                     260.000000     260.000000
# mean                       15.780769       1.630769
# std                         9.419544       1.567717
# min                         0.000000       0.000000
# 25%                        10.000000       0.000000
# 50%                        15.000000       1.000000
# 75%                        20.000000       3.000000
# max                        47.000000       7.000000
#
#        dietary_fiber_(%_daily_value)      sugars     protein  \
# count                     260.000000  260.000000  260.000000
# mean                        6.530769   29.423077   13.338462
# std                         6.307057   28.679797   11.426146
# min                         0.000000    0.000000    0.000000
# 25%                         0.000000    5.750000    4.000000
# 50%                         5.000000   17.500000   12.000000
# 75%                        10.000000   48.000000   19.000000
# max                        28.000000  128.000000   87.000000
#
#        vitamin_a_(%_daily_value)  vitamin_c_(%_daily_value)  \
# count                 260.000000                 260.000000
# mean                   13.426923                   8.534615
# std                    24.366381                  26.345542
# min                     0.000000                   0.000000
# 25%                     2.000000                   0.000000
# 50%                     8.000000                   0.000000
# 75%                    15.000000                   4.000000
# max                   170.000000                 240.000000
#
#        calcium_(%_daily_value)  iron_(%_daily_value)
# count               260.000000            260.000000
# mean                 20.973077              7.734615
# std                  17.019953              8.723263
# min                   0.000000              0.000000
# 25%                   6.000000              0.000000
# 50%                  20.000000              4.000000
# 75%                  30.000000             15.000000
# max                  70.000000             40.000000
#
# [8 rows x 22 columns]

# %%
# Mean, Median, Mode, Std explicitly
summary = pd.DataFrame({
    "Mean": df[numeric_cols].mean(),
    "Median": df[numeric_cols].median(),
    "Mode": df[numeric_cols].mode().iloc[0],
    "Std Dev": df[numeric_cols].std()
})

print(summary)
# Out:
#                                      Mean  Median   Mode     Std Dev
# serving_size                          NaN     NaN    NaN         NaN
# calories                       368.269231   340.0    0.0  240.269886
# calories_from_fat              127.096154   100.0    0.0  127.875914
# total_fat                       14.165385    11.0    0.0   14.205998
# total_fat_(%_daily_value)       21.815385    17.0    0.0   21.885199
# saturated_fat                    6.007692     5.0    0.0    5.321873
# saturated_fat_(%_daily_value)   29.965385    24.0    0.0   26.639209
# trans_fat                        0.203846     0.0    0.0    0.429133
# cholesterol                     54.942308    35.0    0.0   87.269257
# cholesterol_(%_daily_value)     18.392308    11.0    0.0   29.091653
# sodium                         495.750000   190.0  180.0  577.026323
# sodium_(%_daily_value)          20.676923     8.0    6.0   24.034954
# carbohydrates                   47.346154    44.0    0.0   28.252232
# carbohydrates_(%_daily_value)   15.780769    15.0   14.0    9.419544
# dietary_fiber                    1.630769     1.0    1.0    1.567717
# dietary_fiber_(%_daily_value)    6.530769     5.0    0.0    6.307057
# sugars                          29.423077    17.5    0.0   28.679797
# protein                         13.338462    12.0    0.0   11.426146
# vitamin_a_(%_daily_value)       13.426923     8.0    0.0   24.366381
# vitamin_c_(%_daily_value)        8.534615     0.0    0.0   26.345542
# calcium_(%_daily_value)         20.973077    20.0    0.0   17.019953
# iron_(%_daily_value)             7.734615     4.0    0.0    8.723263

# %% [markdown]
# # 3. Time Series Analysis (Conditional)

# %%
print("No date/time column detected — time series analysis skipped.")
# Out:
# No date/time column detected — time series analysis skipped.

# %% [markdown]
# # 4. Customer and Product (Product-Focused) Analysis

# %%
# Category-level aggregation
category_analysis = df.groupby("category")[numeric_cols].mean()
print(category_analysis)
# Out:
#                     serving_size    calories  calories_from_fat  total_fat  \
# category
# Beef & Pork                  NaN  494.000000         224.666667  24.866667
# Beverages                    NaN  113.703704           0.740741   0.092593
# Breakfast                    NaN  526.666667         248.928571  27.690476
# Chicken & Fish               NaN  552.962963         242.222222  26.962963
# Coffee & Tea                 NaN  283.894737          71.105263   8.021053
# Desserts                     NaN  222.142857          64.285714   7.357143
# Salads                       NaN  270.000000         108.333333  11.750000
# Smoothies & Shakes           NaN  531.428571         127.678571  14.125000
# Snacks & Sides               NaN  245.769231          94.615385  10.538462
#
#                     total_fat_(%_daily_value)  saturated_fat  \
# category
# Beef & Pork                         38.600000      10.466667
# Beverages                            0.148148       0.055556
# Breakfast                           42.666667      10.654762
# Chicken & Fish                      41.333333       6.166667
# Coffee & Tea                        12.357895       4.921053
# Desserts                            11.142857       4.285714
# Salads                              18.333333       3.750000
# Smoothies & Shakes                  21.714286       8.375000
# Snacks & Sides                      16.230769       2.692308
#
#                     saturated_fat_(%_daily_value)  trans_fat  cholesterol  \
# category
# Beef & Pork                             52.000000   1.100000    87.333333
# Beverages                                0.296296   0.000000     0.555556
# Breakfast                               53.428571   0.107143   152.857143
# Chicken & Fish                          31.111111   0.129630    75.370370
# Coffee & Tea                            24.368421   0.142105    27.263158
# Desserts                                21.285714   0.000000    15.000000
# Salads                                  18.500000   0.000000    51.666667
# Smoothies & Shakes                      41.785714   0.535714    45.000000
# Snacks & Sides                          13.384615   0.000000    18.461538
#
#                     cholesterol_(%_daily_value)  ...  carbohydrates  \
# category                                         ...
# Beef & Pork                           28.933333  ...      40.133333
# Beverages                              0.185185  ...      28.814815
# Breakfast                             50.952381  ...      49.761905
# Chicken & Fish                        25.222222  ...      49.074074
# Coffee & Tea                           9.378947  ...      44.526316
# Desserts                               4.857143  ...      34.857143
# Salads                                17.333333  ...      21.666667
# Smoothies & Shakes                    14.714286  ...      90.428571
# Snacks & Sides                         6.230769  ...      29.153846
#
#                     carbohydrates_(%_daily_value)  dietary_fiber  \
# category
# Beef & Pork                             13.466667       2.533333
# Beverages                                9.592593       0.037037
# Breakfast                               16.571429       3.261905
# Chicken & Fish                          16.333333       2.925926
# Coffee & Tea                            14.863158       0.778947
# Desserts                                11.571429       1.000000
# Salads                                   7.166667       4.500000
# Smoothies & Shakes                      30.142857       1.464286
# Snacks & Sides                           9.615385       1.538462
#
#                     dietary_fiber_(%_daily_value)     sugars    protein  \
# category
# Beef & Pork                              9.866667   8.800000  27.333333
# Beverages                                0.074074  27.851852   1.333333
# Breakfast                               12.833333   8.261905  19.857143
# Chicken & Fish                          11.814815   7.333333  29.111111
# Coffee & Tea                             3.178947  39.610526   8.863158
# Desserts                                 3.428571  26.142857   4.000000
# Salads                                  18.500000   6.833333  19.833333
# Smoothies & Shakes                       5.750000  77.892857  10.857143
# Snacks & Sides                           7.076923   4.076923   8.384615
#
#                     vitamin_a_(%_daily_value)  vitamin_c_(%_daily_value)  \
# category
# Beef & Pork                          6.933333                   7.333333
# Beverages                            0.740741                  23.481481
# Breakfast                            6.928571                   8.904762
# Chicken & Fish                      20.444444                  12.629630
# Coffee & Tea                        10.736842                   0.000000
# Desserts                             5.142857                   4.142857
# Salads                             146.666667                  28.333333
# Smoothies & Shakes                  18.750000                   6.964286
# Snacks & Sides                       4.846154                  28.153846
#
#                     calcium_(%_daily_value)  iron_(%_daily_value)
# category
# Beef & Pork                       23.000000             23.333333
# Beverages                          2.962963              0.296296
# Breakfast                         16.166667             17.142857
# Chicken & Fish                    15.444444             16.370370
# Coffee & Tea                      28.294737              2.147368
# Desserts                          11.428571              4.000000
# Salads                            15.000000             10.333333
# Smoothies & Shakes                35.571429              3.964286
# Snacks & Sides                     6.000000              6.615385
#
# [9 rows x 22 columns]

# %%
# Highest calorie items
top_calorie_items = df[["item", "calories"]].sort_values(by="calories", ascending=False).head(10)
print(top_calorie_items)
# Out:
#                                                   item  calories
# 82                        Chicken McNuggets (40 piece)      1880
# 32         Big Breakfast with Hotcakes (Large Biscuit)      1150
# 31       Big Breakfast with Hotcakes (Regular Biscuit)      1090
# 34   Big Breakfast with Hotcakes and Egg Whites (La...      1050
# 33   Big Breakfast with Hotcakes and Egg Whites (Re...       990
# 81                        Chicken McNuggets (20 piece)       940
# 253               McFlurry with M&M’s Candies (Medium)       930
# 249                            Chocolate Shake (Large)       850
# 246                           Strawberry Shake (Large)       850
# 251                             Shamrock Shake (Large)       820

# %%
# Correlation analysis
correlation_matrix = df[numeric_cols].corr()
print(correlation_matrix)
# Out:
#                                serving_size  calories  calories_from_fat  \
# serving_size                            NaN       NaN                NaN
# calories                                NaN  1.000000           0.904588
# calories_from_fat                       NaN  0.904588           1.000000
# total_fat                               NaN  0.904409           0.999663
# total_fat_(%_daily_value)               NaN  0.904123           0.999725
# saturated_fat                           NaN  0.845564           0.847008
# saturated_fat_(%_daily_value)           NaN  0.847631           0.849592
# trans_fat                               NaN  0.522441           0.433686
# cholesterol                             NaN  0.596399           0.682161
# cholesterol_(%_daily_value)             NaN  0.595208           0.681607
# sodium                                  NaN  0.712309           0.846624
# sodium_(%_daily_value)                  NaN  0.713415           0.847276
# carbohydrates                           NaN  0.781539           0.461672
# carbohydrates_(%_daily_value)           NaN  0.781242           0.461463
# dietary_fiber                           NaN  0.538894           0.581274
# dietary_fiber_(%_daily_value)           NaN  0.540014           0.575621
# sugars                                  NaN  0.259598          -0.115285
# protein                                 NaN  0.787847           0.807913
# vitamin_a_(%_daily_value)               NaN  0.108844           0.056731
# vitamin_c_(%_daily_value)               NaN -0.068747          -0.087331
# calcium_(%_daily_value)                 NaN  0.428426           0.161034
# iron_(%_daily_value)                    NaN  0.643552           0.735894
#
#                                total_fat  total_fat_(%_daily_value)  \
# serving_size                         NaN                        NaN
# calories                        0.904409                   0.904123
# calories_from_fat               0.999663                   0.999725
# total_fat                       1.000000                   0.999765
# total_fat_(%_daily_value)       0.999765                   1.000000
# saturated_fat                   0.846707                   0.847379
# saturated_fat_(%_daily_value)   0.849293                   0.849973
# trans_fat                       0.431453                   0.433016
# cholesterol                     0.680547                   0.680940
# cholesterol_(%_daily_value)     0.680000                   0.680378
# sodium                          0.846158                   0.846728
# sodium_(%_daily_value)          0.846780                   0.847368
# carbohydrates                   0.461213                   0.460516
# carbohydrates_(%_daily_value)   0.461005                   0.460298
# dietary_fiber                   0.580837                   0.580592
# dietary_fiber_(%_daily_value)   0.575206                   0.575033
# sugars                         -0.115446                  -0.115761
# protein                         0.807773                   0.807922
# vitamin_a_(%_daily_value)       0.054434                   0.054038
# vitamin_c_(%_daily_value)      -0.089354                  -0.089353
# calcium_(%_daily_value)         0.162860                   0.162031
# iron_(%_daily_value)            0.734685                   0.735478
#
#                                saturated_fat  saturated_fat_(%_daily_value)  \
# serving_size                             NaN                            NaN
# calories                            0.845564                       0.847631
# calories_from_fat                   0.847008                       0.849592
# total_fat                           0.846707                       0.849293
# total_fat_(%_daily_value)           0.847379                       0.849973
# saturated_fat                       1.000000                       0.999279
# saturated_fat_(%_daily_value)       0.999279                       1.000000
# trans_fat                           0.620611                       0.620210
# cholesterol                         0.631210                       0.633603
# cholesterol_(%_daily_value)         0.630334                       0.632712
# sodium                              0.584075                       0.588694
# sodium_(%_daily_value)              0.585323                       0.589958
# carbohydrates                       0.591261                       0.591322
# carbohydrates_(%_daily_value)       0.591743                       0.591655
# dietary_fiber                       0.351818                       0.356831
# dietary_fiber_(%_daily_value)       0.347152                       0.351797
# sugars                              0.197734                       0.195928
# protein                             0.603028                       0.606581
# vitamin_a_(%_daily_value)           0.064972                       0.065376
# vitamin_c_(%_daily_value)          -0.179672                      -0.178059
# calcium_(%_daily_value)             0.403311                       0.401139
# iron_(%_daily_value)                0.578062                       0.580488
#
#                                trans_fat  cholesterol  \
# serving_size                         NaN          NaN
# calories                        0.522441     0.596399
# calories_from_fat               0.433686     0.682161
# total_fat                       0.431453     0.680547
# total_fat_(%_daily_value)       0.433016     0.680940
# saturated_fat                   0.620611     0.631210
# saturated_fat_(%_daily_value)   0.620210     0.633603
# trans_fat                       1.000000     0.253935
# cholesterol                     0.253935     1.000000
# cholesterol_(%_daily_value)     0.251502     0.999855
# sodium                          0.187580     0.624362
# sodium_(%_daily_value)          0.188339     0.624743
# carbohydrates                   0.463250     0.270977
# carbohydrates_(%_daily_value)   0.462891     0.272662
# dietary_fiber                   0.054918     0.435575
# dietary_fiber_(%_daily_value)   0.058301     0.440266
# sugars                          0.334756    -0.135518
# protein                         0.388249     0.561561
# vitamin_a_(%_daily_value)       0.075833     0.080239
# vitamin_c_(%_daily_value)      -0.076612    -0.082978
# calcium_(%_daily_value)         0.385331     0.132077
# iron_(%_daily_value)            0.325476     0.655000
#
#                                cholesterol_(%_daily_value)  ...  \
# serving_size                                           NaN  ...
# calories                                          0.595208  ...
# calories_from_fat                                 0.681607  ...
# total_fat                                         0.680000  ...
# total_fat_(%_daily_value)                         0.680378  ...
# saturated_fat                                     0.630334  ...
# saturated_fat_(%_daily_value)                     0.632712  ...
# trans_fat                                         0.251502  ...
# cholesterol                                       0.999855  ...
# cholesterol_(%_daily_value)                       1.000000  ...
# sodium                                            0.623320  ...
# sodium_(%_daily_value)                            0.623720  ...
# carbohydrates                                     0.269300  ...
# carbohydrates_(%_daily_value)                     0.270992  ...
# dietary_fiber                                     0.434940  ...
# dietary_fiber_(%_daily_value)                     0.439814  ...
# sugars                                           -0.136459  ...
# protein                                           0.560957  ...
# vitamin_a_(%_daily_value)                         0.080059  ...
# vitamin_c_(%_daily_value)                        -0.083315  ...
# calcium_(%_daily_value)                           0.132382  ...
# iron_(%_daily_value)                              0.653167  ...
#
#                                carbohydrates  carbohydrates_(%_daily_value)  \
# serving_size                             NaN                            NaN
# calories                            0.781539                       0.781242
# calories_from_fat                   0.461672                       0.461463
# total_fat                           0.461213                       0.461005
# total_fat_(%_daily_value)           0.460516                       0.460298
# saturated_fat                       0.591261                       0.591743
# saturated_fat_(%_daily_value)       0.591322                       0.591655
# trans_fat                           0.463250                       0.462891
# cholesterol                         0.270977                       0.272662
# cholesterol_(%_daily_value)         0.269300                       0.270992
# sodium                              0.200796                       0.201032
# sodium_(%_daily_value)              0.202426                       0.202663
# carbohydrates                       1.000000                       0.999620
# carbohydrates_(%_daily_value)       0.999620                       1.000000
# dietary_fiber                       0.224577                       0.224058
# dietary_fiber_(%_daily_value)       0.228257                       0.227285
# sugars                              0.762362                       0.762282
# protein                             0.352122                       0.352178
# vitamin_a_(%_daily_value)           0.083802                       0.083376
# vitamin_c_(%_daily_value)          -0.034724                      -0.035450
# calcium_(%_daily_value)             0.589699                       0.590263
# iron_(%_daily_value)                0.210241                       0.210643
#
#                                dietary_fiber  dietary_fiber_(%_daily_value)  \
# serving_size                             NaN                            NaN
# calories                            0.538894                       0.540014
# calories_from_fat                   0.581274                       0.575621
# total_fat                           0.580837                       0.575206
# total_fat_(%_daily_value)           0.580592                       0.575033
# saturated_fat                       0.351818                       0.347152
# saturated_fat_(%_daily_value)       0.356831                       0.351797
# trans_fat                           0.054918                       0.058301
# cholesterol                         0.435575                       0.440266
# cholesterol_(%_daily_value)         0.434940                       0.439814
# sodium                              0.694389                       0.689995
# sodium_(%_daily_value)              0.693913                       0.689464
# carbohydrates                       0.224577                       0.228257
# carbohydrates_(%_daily_value)       0.224058                       0.227285
# dietary_fiber                       1.000000                       0.986350
# dietary_fiber_(%_daily_value)       0.986350                       1.000000
# sugars                             -0.295178                      -0.287014
# protein                             0.641345                       0.656648
# vitamin_a_(%_daily_value)           0.340518                       0.361380
# vitamin_c_(%_daily_value)           0.141935                       0.150019
# calcium_(%_daily_value)             0.028711                       0.052359
# iron_(%_daily_value)                0.740411                       0.737814
#
#                                  sugars   protein  vitamin_a_(%_daily_value)  \
# serving_size                        NaN       NaN                        NaN
# calories                       0.259598  0.787847                   0.108844
# calories_from_fat             -0.115285  0.807913                   0.056731
# total_fat                     -0.115446  0.807773                   0.054434
# total_fat_(%_daily_value)     -0.115761  0.807922                   0.054038
# saturated_fat                  0.197734  0.603028                   0.064972
# saturated_fat_(%_daily_value)  0.195928  0.606581                   0.065376
# trans_fat                      0.334756  0.388249                   0.075833
# cholesterol                   -0.135518  0.561561                   0.080239
# cholesterol_(%_daily_value)   -0.136459  0.560957                   0.080059
# sodium                        -0.426536  0.869802                   0.083068
# sodium_(%_daily_value)        -0.424943  0.869870                   0.083259
# carbohydrates                  0.762362  0.352122                   0.083802
# carbohydrates_(%_daily_value)  0.762282  0.352178                   0.083376
# dietary_fiber                 -0.295178  0.641345                   0.340518
# dietary_fiber_(%_daily_value) -0.287014  0.656648                   0.361380
# sugars                         1.000000 -0.179940                   0.048488
# protein                       -0.179940  1.000000                   0.214098
# vitamin_a_(%_daily_value)      0.048488  0.214098                   1.000000
# vitamin_c_(%_daily_value)     -0.069847 -0.045777                   0.069171
# calcium_(%_daily_value)        0.600093  0.327971                   0.179190
# iron_(%_daily_value)          -0.364767  0.792719                   0.137879
#
#                                vitamin_c_(%_daily_value)  \
# serving_size                                         NaN
# calories                                       -0.068747
# calories_from_fat                              -0.087331
# total_fat                                      -0.089354
# total_fat_(%_daily_value)                      -0.089353
# saturated_fat                                  -0.179672
# saturated_fat_(%_daily_value)                  -0.178059
# trans_fat                                      -0.076612
# cholesterol                                    -0.082978
# cholesterol_(%_daily_value)                    -0.083315
# sodium                                         -0.030769
# sodium_(%_daily_value)                         -0.030945
# carbohydrates                                  -0.034724
# carbohydrates_(%_daily_value)                  -0.035450
# dietary_fiber                                   0.141935
# dietary_fiber_(%_daily_value)                   0.150019
# sugars                                         -0.069847
# protein                                        -0.045777
# vitamin_a_(%_daily_value)                       0.069171
# vitamin_c_(%_daily_value)                       1.000000
# calcium_(%_daily_value)                        -0.215380
# iron_(%_daily_value)                            0.001292
#
#                                calcium_(%_daily_value)  iron_(%_daily_value)
# serving_size                                       NaN                   NaN
# calories                                      0.428426              0.643552
# calories_from_fat                             0.161034              0.735894
# total_fat                                     0.162860              0.734685
# total_fat_(%_daily_value)                     0.162031              0.735478
# saturated_fat                                 0.403311              0.578062
# saturated_fat_(%_daily_value)                 0.401139              0.580488
# trans_fat                                     0.385331              0.325476
# cholesterol                                   0.132077              0.655000
# cholesterol_(%_daily_value)                   0.132382              0.653167
# sodium                                       -0.024074              0.871593
# sodium_(%_daily_value)                       -0.022145              0.870742
# carbohydrates                                 0.589699              0.210241
# carbohydrates_(%_daily_value)                 0.590263              0.210643
# dietary_fiber                                 0.028711              0.740411
# dietary_fiber_(%_daily_value)                 0.052359              0.737814
# sugars                                        0.600093             -0.364767
# protein                                       0.327971              0.792719
# vitamin_a_(%_daily_value)                     0.179190              0.137879
# vitamin_c_(%_daily_value)                    -0.215380              0.001292
# calcium_(%_daily_value)                       1.000000              0.034149
# iron_(%_daily_value)                          0.034149              1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# # 5. Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Bar chart: Average calories by category
plt.figure()
df.groupby("category")["calories"].mean().sort_values().plot(kind="bar")
plt.title("Average Calories by Category")
plt.ylabel("Calories")
plt.show()

# %%
# Distribution plot: Calories
plt.figure()
sns.histplot(df["calories"], bins=30, kde=True)
plt.title("Calorie Distribution")
plt.show()

# %%
# Heatmap: Nutrient correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Nutritional Correlation Heatmap")
plt.show()

# %% [markdown]
# # 6. Actionable Recommendations (Data-Driven Logic)

# %%
# Identify high-calorie, low-protein items
df["calorie_to_protein_ratio"] = df["calories"] / (df["protein"] + 1)

risk_items = df.sort_values(by="calorie_to_protein_ratio", ascending=False).head(10)
print("Items with poor calorie-to-protein ratio:")
print(risk_items[["item", "calories", "protein", "calorie_to_protein_ratio"]])
# Out:
# Items with poor calorie-to-protein ratio:
#                            item  calories  protein  calorie_to_protein_ratio
# 112   Coca-Cola Classic (Large)       280        0                     280.0
# 128              Sprite (Large)       280        0                     280.0
# 120           Dr Pepper (Large)       270        0                     270.0
# 111  Coca-Cola Classic (Medium)       200        0                     200.0
# 127             Sprite (Medium)       200        0                     200.0
# 119          Dr Pepper (Medium)       190        0                     190.0
# 110   Coca-Cola Classic (Small)       140        0                     140.0
# 126              Sprite (Small)       140        0                     140.0
# 118           Dr Pepper (Small)       140        0                     140.0
# 143           Sweet Tea (Large)       220        1                     110.0

# %%
# Healthier menu candidates
healthy_items = df[
    (df["calories"] < df["calories"].median()) &
    (df["protein"] > df["protein"].median())
].sort_values(by="protein", ascending=False)

print("Health-oriented menu items:")
print(healthy_items[["item", "calories", "protein"]].head(10))
# Out:
# Health-oriented menu items:
#                                                   item  calories  protein
# 86      Premium Bacon Ranch Salad with Grilled Chicken       220       29
# 89        Premium Southwest Salad with Grilled Chicken       290       27
# 1                                    Egg White Delight       250       18
# 0                                         Egg McMuffin       300       17
# 177  Nonfat Latte with Sugar Free French Vanilla Sy...       220       16
# 91           Chipotle BBQ Snack Wrap (Grilled Chicken)       260       16
# 93          Honey Mustard Snack Wrap (Grilled Chicken)       250       16
# 95                  Ranch Snack Wrap (Grilled Chicken)       280       16
# 171                      Nonfat Hazelnut Latte (Large)       310       16
# 168                       Nonfat Caramel Latte (Large)       310       16

# %% [markdown]
# # Completed
